# %%
import pandas as pd

# %%
df = pd.read_csv('../data/recidivism.csv')

# %%
df.columns
# Out:
# Index(['Fiscal Year Released', 'Recidivism Reporting Year',
#        'Main Supervising District', 'Release Type', 'Race - Ethnicity',
#        'Age At Release ', 'Sex', 'Offense Classification', 'Offense Type',
#        'Offense Subtype', 'Return to Prison', 'Days to Return',
#        'Recidivism Type', 'New Offense Classification', 'New Offense Type',
#        'New Offense Sub Type', 'Target Population'],
#       dtype='object')

# %%
df = df[['Fiscal Year Released','Sex','Release Type','Race - Ethnicity','Offense Classification','Offense Type','Offense Subtype','Return to Prison']]

# %%
df
# Out:
#        Fiscal Year Released     Sex                        Release Type  \
# 0                      2010    Male                              Parole
# 1                      2010    Male        Discharged – End of Sentence
# 2                      2010    Male                              Parole
# 3                      2010    Male                              Parole
# 4                      2010    Male        Discharged – End of Sentence
# ...                     ...     ...                                 ...
# 26015                  2015    Male           Paroled to Detainer - INS
# 26016                  2015    Male        Released to Special Sentence
# 26017                  2015  Female                      Parole Granted
# 26018                  2015    Male       Paroled w/Immediate Discharge
# 26019                  2015    Male  Paroled to Detainer - Out of State
#
#            Race - Ethnicity  Offense Classification  Offense Type  \
# ...

# %%
df = df[df.Sex=='Male']
df.drop('Sex',inplace=True,axis=1)
# Out:
# /Users/designwork/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
for col in df.columns:
    print(df[col].value_counts(),'\n\n')
# Out:
# 2012    4186
# 2013    4043
# 2014    3969
# 2015    3753
# 2011    3418
# 2010    3309
# Name: Fiscal Year Released, dtype: int64
#
#
# Parole                                 8375
# Parole Granted                         4632
# Discharged – End of Sentence           4563
# Discharged - Expiration of Sentence    2151
# Released to Special Sentence            396
# Special Sentence                        343
# Paroled w/Immediate Discharge           247
# Paroled to Detainer - INS               129
# Paroled to Detainer - Out of State      110
# Paroled to Detainer - U.S. Marshall      74
# Paroled to Detainer - Iowa               57
# Name: Release Type, dtype: int64
#
#
# White - Non-Hispanic                               15121
# Black - Non-Hispanic                                5475
# White - Hispanic                                    1411
# American Indian or Alaska Native - Non-Hispanic      407
# Asian or Pacific Islander - Non-Hispanic             171
# ...

# %% [markdown]
# ## Clean Null Rows

# %%
df.isna().sum()
# Out:
# Fiscal Year Released         0
# Release Type              1601
# Race - Ethnicity            27
# Offense Classification       0
# Offense Type                 0
# Offense Subtype              0
# Return to Prison             0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-38-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
newdf = pd.get_dummies(df[['Release Type','Offense Classification',
       'Offense Type', 'Offense Subtype']])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encodeRecidivism = {'No': -1, 'Yes': 1}

# %%
def encodeRace(x):
    if 'White - Non-Hispanic' in x:
        return 1
    else:
        return -1

# %%
def encodeRace2(x):
    if 'White' in x:
        return 1
    else:
        return -1

# %%
def encodeRecidivism(x):
    if x == 'No':
        return -1
    elif x == 'Yes':
        return 1
    else:
        return 0

# %%
newdf['Race'] = df['Race - Ethnicity'].apply(lambda x: encodeRace(x))

# %%
newdf['Recidivism'] = df['Return to Prison'].apply(lambda x: encodeRecidivism(x))

# %%
newdf
# Out:
#        Release Type_Discharged - Expiration of Sentence  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 26013                                                 0
# 26015                                                 0
# 26016                                                 0
# 26018                                                 0
# 26019                                                 0
#
#        Release Type_Discharged – End of Sentence  Release Type_Parole  \
# 0                                              0                    1
# 1                                              1                    0
# 2                                              0                    1
# ...

# %%
newdf.to_csv('recividism_white_nonwhite.csv',index=False)

# %%
def check_distr(newdf):
    print('race = -1')
    print(len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==1)])/(len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==-1)])+len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==1)])) )
    print('race = 1')

# %%
len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==1)])/(len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==-1)])+len(newdf[(newdf['Race']==-1) & (newdf['Recidivism']==1)]))
# Out:
# 0.32795853728764757

# %%
len(newdf[(newdf['Race']==1) & (newdf['Recidivism']==1)])/(len(newdf[(newdf['Race']==1) & (newdf['Recidivism']==-1)])+len(newdf[(newdf['Race']==1) & (newdf['Recidivism']==1)]))
# Out:
# 0.36074872376630746

# %%
# Out:
#        Release Type_Discharged - Expiration of Sentence  \
# 3                                                     0
# 5                                                     0
# 6                                                     0
# 8                                                     0
# 13                                                    0
# ...                                                 ...
# 26010                                                 0
# 26012                                                 1
# 26013                                                 0
# 26016                                                 0
# 26018                                                 0
#
#        Release Type_Discharged – End of Sentence  Release Type_Parole  \
# 3                                              0                    1
# 5                                              0                    1
# 6                                              0                    1
# ...

# %%
def encodeRace(x):
    if 'Black' in x:
        return 1
    elif 'White' in x:
        return -1
    else:
        return 0
