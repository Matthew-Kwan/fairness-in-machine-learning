# %%
import pandas as pd

# %%
df = pd.read_csv('../data/recidivism.csv')

# %%
df.columns
# Out:
# Index(['Fiscal Year Released', 'Recidivism Reporting Year',
#        'Main Supervising District', 'Release Type', 'Race - Ethnicity',
#        'Age At Release ', 'Sex', 'Offense Classification', 'Offense Type',
#        'Offense Subtype', 'Return to Prison', 'Days to Return',
#        'Recidivism Type', 'New Offense Classification', 'New Offense Type',
#        'New Offense Sub Type', 'Target Population'],
#       dtype='object')

# %%
df = df[['Sex','Release Type','Race - Ethnicity','Offense Classification','Offense Type','Offense Subtype','Return to Prison']]

# %%
df
# Out:
#           Sex                        Release Type      Race - Ethnicity  \
# 0        Male                              Parole  Black - Non-Hispanic
# 1        Male        Discharged – End of Sentence  White - Non-Hispanic
# 2        Male                              Parole  White - Non-Hispanic
# 3        Male                              Parole  White - Non-Hispanic
# 4        Male        Discharged – End of Sentence  Black - Non-Hispanic
# ...       ...                                 ...                   ...
# 26015    Male           Paroled to Detainer - INS      White - Hispanic
# 26016    Male        Released to Special Sentence  White - Non-Hispanic
# 26017  Female                      Parole Granted  White - Non-Hispanic
# 26018    Male       Paroled w/Immediate Discharge  White - Non-Hispanic
# 26019    Male  Paroled to Detainer - Out of State  White - Non-Hispanic
#
#        Offense Classification  Offense Type      Offense Subtype  \
# ...

# %%
df = df[df.Sex=='Male']
df.drop('Sex',inplace=True,axis=1)
# Out:
# /Users/designwork/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
for col in df.columns:
    print(df[col].value_counts(),'\n\n')
# Out:
# Parole                                 8375
# Parole Granted                         4632
# Discharged – End of Sentence           4563
# Discharged - Expiration of Sentence    2151
# Released to Special Sentence            396
# Special Sentence                        343
# Paroled w/Immediate Discharge           247
# Paroled to Detainer - INS               129
# Paroled to Detainer - Out of State      110
# Paroled to Detainer - U.S. Marshall      74
# Paroled to Detainer - Iowa               57
# Name: Release Type, dtype: int64
#
#
# White - Non-Hispanic                               15121
# Black - Non-Hispanic                                5475
# White - Hispanic                                    1411
# American Indian or Alaska Native - Non-Hispanic      407
# Asian or Pacific Islander - Non-Hispanic             171
# Black - Hispanic                                      34
# White -                                               12
# ...

# %% [markdown]
# ## Clean Null Rows

# %%
df.isna().sum()
# Out:
# Release Type              0
# Race - Ethnicity          0
# Offense Classification    0
# Offense Type              0
# Offense Subtype           0
# Return to Prison          0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-48-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
newdf = pd.get_dummies(df[['Release Type', 'Race - Ethnicity', 'Offense Classification',
       'Offense Type', 'Offense Subtype', 'Return to Prison', 'Recidivism']])

# %%
df.columns
# Out:
# Index(['Release Type', 'Race - Ethnicity', 'Offense Classification',
#        'Offense Type', 'Offense Subtype', 'Return to Prison', 'Recidivism'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encodeRecidivism = {'No': -1, 'Yes': 1}

# %%
def encodeRace(x):
    if 'Black' in x:
        return 1
    else:
        return -1

# %%
def encodeRecidivism(x):
    if x == 'No':
        return -1
    elif x == 'Yes':
        return 1
    else:
        return 0

# %%
df['Race - Ethnicity'].apply(lambda x: encodeRace(x))
# Out:
# 0        1
# 1       -1
# 2       -1
# 3       -1
# 4        1
#         ..
# 26013   -1
# 26015   -1
# 26016   -1
# 26018   -1
# 26019   -1
# Name: Race - Ethnicity, Length: 21050, dtype: int64

# %%
df['Recidivism'] = df['Return to Prison'].apply(lambda x: encodeRecidivism(x))
# Out:
# <ipython-input-77-edfbf6d1e92e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Recidivism'] = df['Return to Prison'].apply(lambda x: encodeRecidivism(x))

# %%
dummies
# Out:
#        Release Type_Discharged - Expiration of Sentence  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 26013                                                 0
# 26015                                                 0
# 26016                                                 0
# 26018                                                 0
# 26019                                                 0
#
#        Release Type_Discharged – End of Sentence  Release Type_Parole  \
# 0                                              0                    1
# 1                                              1                    0
# 2                                              0                    1
# ...
